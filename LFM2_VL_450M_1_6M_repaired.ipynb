# %% [markdown]
# # Notebook recovered
# - Repaired on: 2025-08-20T00:09:03.992070Z
# - Original file was corrupted and missing the required `cells` key.
# - This is an auto-generated recovery cell so the notebook is structurally valid.
#
# You can add new cells below. If you have a previous script/output, paste it here.
