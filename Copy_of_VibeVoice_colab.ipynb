# %% [markdown]
# <a href="https://colab.research.google.com/github/Jalam1001/AI_AGENT_RESEARCH/blob/main/Copy_of_VibeVoice_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # VibeVoice Colab — T4 Quickstart (1.5B)
# This page provides a quickstart guide to run VibeVoice on Colab with T4.
#
# The T4 GPU can only support the 1.5B model due to memory limitations. Please note that T4 can only use SDPA instead of flash_attention_2, which may result in unstable and lower audio quality. For the best TTS experience, we recommend trying the 7B model on a more powerful GPU.

# %% [markdown]
# ## Step 1: Use T4

# %% [markdown]
# Use T4 in Colab: go to Runtime → Change runtime type → Hardware accelerator: GPU → T4.

# %%
import torch
print(torch.cuda.is_available())
# !nvidia-smi
# Out:
# True
# Thu Aug 28 15:57:43 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   50C    P8             10W /   70W |       2MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ## Step 2: Env Install

# %%
# !git clone https://github.com/microsoft/VibeVoice.git

import os
os.chdir("./VibeVoice")

# !apt update && apt install ffmpeg -y
# !pip install -e .
# Out:
# Cloning into 'VibeVoice'...
# remote: Enumerating objects: 360, done.
# remote: Counting objects: 100% (112/112), done.
# remote: Compressing objects: 100% (73/73), done.
# remote: Total 360 (delta 68), reused 52 (delta 39), pack-reused 248 (from 2)
# Receiving objects: 100% (360/360), 87.49 MiB | 42.18 MiB/s, done.
# Resolving deltas: 100% (166/166), done.
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:2 https://cli.github.com/packages stable InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,272 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,295 kB]
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:13 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [5,332 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:15 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,199 kB]
# Get:16 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,782 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [5,526 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,576 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,608 kB]
# Fetched 33.0 MB in 3s (9,582 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 37 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.
# Obtaining file:///content/VibeVoice
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from vibevoice==0.0.1) (2.8.0+cu126)
# Collecting accelerate==1.6.0 (from vibevoice==0.0.1)
#   Downloading accelerate-1.6.0-py3-none-any.whl.metadata (19 kB)
# Collecting transformers==4.51.3 (from vibevoice==0.0.1)
#   Downloading transformers-4.51.3-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: diffusers in /usr/local/lib/python3.12/dist-packages (from vibevoice==0.0.1) (0.35.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from vibevoice==0.0.1) (4.67.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from vibevoice==0.0.1) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from vibevoice==0.0.1) (1.16.1)
# Requirement already satisfied: librosa in /usr/local/lib/python3.12/dist-packages (from vibevoice==0.0.1) (0.11.0)
# Collecting ml-collections (from vibevoice==0.0.1)
#   Downloading ml_collections-1.1.0-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from vibevoice==0.0.1) (1.4.0)
# Requirement already satisfied: gradio in /usr/local/lib/python3.12/dist-packages (from vibevoice==0.0.1) (5.43.1)
# Collecting av (from vibevoice==0.0.1)
#   Downloading av-15.0.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (4.6 kB)
# Collecting aiortc (from vibevoice==0.0.1)
#   Downloading aiortc-1.13.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from accelerate==1.6.0->vibevoice==0.0.1) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate==1.6.0->vibevoice==0.0.1) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate==1.6.0->vibevoice==0.0.1) (6.0.2)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from accelerate==1.6.0->vibevoice==0.0.1) (0.34.4)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate==1.6.0->vibevoice==0.0.1) (0.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers==4.51.3->vibevoice==0.0.1) (3.19.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.51.3->vibevoice==0.0.1) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers==4.51.3->vibevoice==0.0.1) (2.32.4)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.12/dist-packages (from transformers==4.51.3->vibevoice==0.0.1) (0.21.4)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->vibevoice==0.0.1) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->vibevoice==0.0.1) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->vibevoice==0.0.1) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch->vibevoice==0.0.1) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->vibevoice==0.0.1) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch->vibevoice==0.0.1) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->vibevoice==0.0.1) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->vibevoice==0.0.1) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->vibevoice==0.0.1) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->vibevoice==0.0.1) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->vibevoice==0.0.1) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->vibevoice==0.0.1) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->vibevoice==0.0.1) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->vibevoice==0.0.1) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->vibevoice==0.0.1) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->vibevoice==0.0.1) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch->vibevoice==0.0.1) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->vibevoice==0.0.1) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->vibevoice==0.0.1) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->vibevoice==0.0.1) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch->vibevoice==0.0.1) (3.4.0)
# Collecting aioice<1.0.0,>=0.10.1 (from aiortc->vibevoice==0.0.1)
#   Downloading aioice-0.10.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting av (from vibevoice==0.0.1)
#   Downloading av-14.4.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.6 kB)
# Requirement already satisfied: cffi>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from aiortc->vibevoice==0.0.1) (1.17.1)
# Collecting cryptography>=44.0.0 (from aiortc->vibevoice==0.0.1)
#   Downloading cryptography-45.0.6-cp311-abi3-manylinux_2_34_x86_64.whl.metadata (5.7 kB)
# Requirement already satisfied: google-crc32c>=1.1 in /usr/local/lib/python3.12/dist-packages (from aiortc->vibevoice==0.0.1) (1.7.1)
# Collecting pyee>=13.0.0 (from aiortc->vibevoice==0.0.1)
#   Downloading pyee-13.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting pylibsrtp>=0.10.0 (from aiortc->vibevoice==0.0.1)
#   Downloading pylibsrtp-0.12.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Collecting pyopenssl>=25.0.0 (from aiortc->vibevoice==0.0.1)
#   Downloading pyopenssl-25.1.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.12/dist-packages (from diffusers->vibevoice==0.0.1) (8.7.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from diffusers->vibevoice==0.0.1) (11.3.0)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.12/dist-packages (from gradio->vibevoice==0.0.1) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio->vibevoice==0.0.1) (4.10.0)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from gradio->vibevoice==0.0.1) (1.1.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.12/dist-packages (from gradio->vibevoice==0.0.1) (0.116.1)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio->vibevoice==0.0.1) (0.6.1)
# Requirement already satisfied: gradio-client==1.12.1 in /usr/local/lib/python3.12/dist-packages (from gradio->vibevoice==0.0.1) (1.12.1)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio->vibevoice==0.0.1) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from gradio->vibevoice==0.0.1) (0.28.1)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio->vibevoice==0.0.1) (3.0.2)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio->vibevoice==0.0.1) (3.11.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio->vibevoice==0.0.1) (2.2.2)
# Requirement already satisfied: pydantic<2.12,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio->vibevoice==0.0.1) (2.11.7)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from gradio->vibevoice==0.0.1) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from gradio->vibevoice==0.0.1) (0.0.20)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.12/dist-packages (from gradio->vibevoice==0.0.1) (0.12.10)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from gradio->vibevoice==0.0.1) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio->vibevoice==0.0.1) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from gradio->vibevoice==0.0.1) (0.47.3)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio->vibevoice==0.0.1) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.12/dist-packages (from gradio->vibevoice==0.0.1) (0.16.1)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio->vibevoice==0.0.1) (0.35.0)
# Requirement already satisfied: websockets<16.0,>=10.0 in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.12.1->gradio->vibevoice==0.0.1) (15.0.1)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.12/dist-packages (from librosa->vibevoice==0.0.1) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.12/dist-packages (from librosa->vibevoice==0.0.1) (0.60.0)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from librosa->vibevoice==0.0.1) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa->vibevoice==0.0.1) (1.5.1)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from librosa->vibevoice==0.0.1) (4.4.2)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.12/dist-packages (from librosa->vibevoice==0.0.1) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.12/dist-packages (from librosa->vibevoice==0.0.1) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from librosa->vibevoice==0.0.1) (0.5.0.post1)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.12/dist-packages (from librosa->vibevoice==0.0.1) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa->vibevoice==0.0.1) (1.1.1)
# Collecting dnspython>=2.0.0 (from aioice<1.0.0,>=0.10.1->aiortc->vibevoice==0.0.1)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting ifaddr>=0.2.0 (from aioice<1.0.0,>=0.10.1->aiortc->vibevoice==0.0.1)
#   Downloading ifaddr-0.2.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0,>=3.0->gradio->vibevoice==0.0.1) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0,>=3.0->gradio->vibevoice==0.0.1) (1.3.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.0->aiortc->vibevoice==0.0.1) (2.22)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio->vibevoice==0.0.1) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio->vibevoice==0.0.1) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio->vibevoice==0.0.1) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.21.0->accelerate==1.6.0->vibevoice==0.0.1) (1.1.8)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51.0->librosa->vibevoice==0.0.1) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio->vibevoice==0.0.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio->vibevoice==0.0.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio->vibevoice==0.0.1) (2025.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa->vibevoice==0.0.1) (4.3.8)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.0->gradio->vibevoice==0.0.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.0->gradio->vibevoice==0.0.1) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.0->gradio->vibevoice==0.0.1) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.51.3->vibevoice==0.0.1) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.51.3->vibevoice==0.0.1) (2.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.1.0->librosa->vibevoice==0.0.1) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->vibevoice==0.0.1) (1.3.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio->vibevoice==0.0.1) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio->vibevoice==0.0.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio->vibevoice==0.0.1) (13.9.4)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib_metadata->diffusers->vibevoice==0.0.1) (3.23.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio->vibevoice==0.0.1) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio->vibevoice==0.0.1) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio->vibevoice==0.0.1) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio->vibevoice==0.0.1) (0.1.2)
# Downloading accelerate-1.6.0-py3-none-any.whl (354 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 354.7/354.7 kB 9.2 MB/s eta 0:00:00
# Downloading transformers-4.51.3-py3-none-any.whl (10.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 105.5 MB/s eta 0:00:00
# Downloading aiortc-1.13.0-py3-none-any.whl (92 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 9.0 MB/s eta 0:00:00
# Downloading av-14.4.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.5/35.5 MB 24.2 MB/s eta 0:00:00
# Downloading ml_collections-1.1.0-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 7.3 MB/s eta 0:00:00
# Downloading aioice-0.10.1-py3-none-any.whl (24 kB)
# Downloading cryptography-45.0.6-cp311-abi3-manylinux_2_34_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 93.2 MB/s eta 0:00:00
# Downloading pyee-13.0.0-py3-none-any.whl (15 kB)
# Downloading pylibsrtp-0.12.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 95.4 MB/s eta 0:00:00
# Downloading pyopenssl-25.1.0-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 6.0 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 27.9 MB/s eta 0:00:00
# Downloading ifaddr-0.2.0-py3-none-any.whl (12 kB)
# Building wheels for collected packages: vibevoice
#   Building editable for vibevoice (pyproject.toml) ... done
#   Created wheel for vibevoice: filename=vibevoice-0.0.1-0.editable-py3-none-any.whl size=8169 sha256=b0b9bbd7c9e95004d8b7c240c89e2482f315591b1c900825e451221f32570728
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nihbe1ql/wheels/9a/bc/f4/9472739ad0b2e360b35149e04e301893e223eb10883b4e98cc
# Successfully built vibevoice
# Installing collected packages: ifaddr, pyee, ml-collections, dnspython, av, pylibsrtp, cryptography, aioice, pyopenssl, transformers, aiortc, accelerate, vibevoice
#   Attempting uninstall: cryptography
#     Found existing installation: cryptography 43.0.3
#     Uninstalling cryptography-43.0.3:
#       Successfully uninstalled cryptography-43.0.3
#   Attempting uninstall: pyopenssl
#     Found existing installation: pyOpenSSL 24.2.1
#     Uninstalling pyOpenSSL-24.2.1:
#       Successfully uninstalled pyOpenSSL-24.2.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.55.4
#     Uninstalling transformers-4.55.4:
#       Successfully uninstalled transformers-4.55.4
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 1.10.1
#     Uninstalling accelerate-1.10.1:
#       Successfully uninstalled accelerate-1.10.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pydrive2 1.21.3 requires cryptography<44, but you have cryptography 45.0.6 which is incompatible.
# pydrive2 1.21.3 requires pyOpenSSL<=24.2.1,>=19.1.0, but you have pyopenssl 25.1.0 which is incompatible.
# Successfully installed accelerate-1.6.0 aioice-0.10.1 aiortc-1.13.0 av-14.4.0 cryptography-45.0.6 dnspython-2.7.0 ifaddr-0.2.0 ml-collections-1.1.0 pyee-13.0.0 pylibsrtp-0.12.0 pyopenssl-25.1.0 transformers-4.51.3 vibevoice-0.0.1

# %% [markdown]
# ## Step 3: Run VibeVoice

# %%
# First download checkpoint takes ~3 minutes
# !python demo/inference_from_file.py --model_path microsoft/VibeVoice-1.5B --txt_path demo/text_examples/2p_short.txt --speaker_names Alice Frank

from IPython.display import Audio
Audio("./outputs/2p_short_generated.wav")
# Out:
# 2025-08-28 15:59:34.386305: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1756396774.403368    2255 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1756396774.409272    2255 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1756396774.424563    2255 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1756396774.424594    2255 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1756396774.424598    2255 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1756396774.424601    2255 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-08-28 15:59:34.429487: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:vibevoice.modular.modular_vibevoice_tokenizer:APEX FusedRMSNorm not available, using native implementation
# Found 9 voice files in /content/VibeVoice/demo/voices
# Available voices: en-Alice_woman, en-Carter_man, en-Frank_man, en-Mary_woman_bgm, en-Maya_woman, in-Samuel_man, zh-Anchen_man_bgm, zh-Bowen_man, zh-Xinran_woman
# Reading script from: demo/text_examples/2p_short.txt
# Found 2 speaker segments:
#   1. Speaker 1
#      Text preview: Speaker 1: I heard there’s big news in TTS lately?...
#   2. Speaker 2
#      Text preview: Speaker 2: Yes! Microsoft Research just open-sourced VibeVoice. The model can generate speech up to ...
#
# Speaker mapping:
#   Speaker 2 -> Frank
#   Speaker 1 -> Alice
# Speaker 1 ('Alice') -> Voice: en-Alice_woman.wav
# Speaker 2 ('Frank') -> Voice: en-Frank_man.wav
# Loading processor & model from microsoft/VibeVoice-1.5B
# WARNING:vibevoice.processor.vibevoice_processor:No preprocessor_config.json found at microsoft/VibeVoice-1.5B, using defaults
# tokenizer_config.json: 7.23kB [00:00, 23.4MB/s]
# vocab.json: 2.78MB [00:00, 31.1MB/s]
# merges.txt: 1.67MB [00:00, 102MB/s]
# tokenizer.json: 7.03MB [00:00, 142MB/s]
# loading file vocab.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B/snapshots/8faed761d45a263340a0528343f099c05c9a4323/vocab.json
# loading file merges.txt from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B/snapshots/8faed761d45a263340a0528343f099c05c9a4323/merges.txt
# loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B/snapshots/8faed761d45a263340a0528343f099c05c9a4323/tokenizer.json
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at None
# loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B/snapshots/8faed761d45a263340a0528343f099c05c9a4323/tokenizer_config.json
# loading file chat_template.jinja from cache at None
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'Qwen2Tokenizer'.
# The class this function is called from is 'VibeVoiceTextTokenizerFast'.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json: 2.76kB [00:00, 15.5MB/s]
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--microsoft--VibeVoice-1.5B/snapshots/cf42b8ff262f8a286bcbe580835cfaad62d277ca/config.json
# Model config VibeVoiceConfig {
#   "acoustic_tokenizer_config": {
#     "causal": true,
#     "channels": 1,
#     "conv_bias": true,
#     "conv_norm": "none",
#     "corpus_normalize": 0.0,
#     "decoder_depths": null,
#     "decoder_n_filters": 32,
#     "decoder_ratios": [
#       8,
#       5,
#       5,
#       4,
#       2,
#       2
#     ],
#     "disable_last_norm": true,
#     "encoder_depths": "3-3-3-3-3-3-8",
#     "encoder_n_filters": 32,
#     "encoder_ratios": [
#       8,
#       5,
#       5,
#       4,
#       2,
#       2
#     ],
#     "fix_std": 0.5,
#     "layer_scale_init_value": 1e-06,
#     "layernorm": "RMSNorm",
#     "layernorm_elementwise_affine": true,
#     "layernorm_eps": 1e-05,
#     "mixer_layer": "depthwise_conv",
#     "model_type": "vibevoice_acoustic_tokenizer",
#     "pad_mode": "constant",
#     "std_dist_type": "gaussian",
#     "vae_dim": 64,
#     "weight_init_value": 0.01
#   },
#   "acoustic_vae_dim": 64,
#   "architectures": [
#     "VibeVoiceForConditionalGeneration"
#   ],
#   "decoder_config": {
#     "attention_dropout": 0.0,
#     "hidden_act": "silu",
#     "hidden_size": 1536,
#     "initializer_range": 0.02,
#     "intermediate_size": 8960,
#     "max_position_embeddings": 65536,
#     "max_window_layers": 28,
#     "model_type": "qwen2",
#     "num_attention_heads": 12,
#     "num_hidden_layers": 28,
#     "num_key_value_heads": 2,
#     "rms_norm_eps": 1e-06,
#     "rope_scaling": null,
#     "rope_theta": 1000000.0,
#     "sliding_window": null,
#     "tie_word_embeddings": true,
#     "torch_dtype": "bfloat16",
#     "use_cache": true,
#     "use_sliding_window": false,
#     "vocab_size": 151936
#   },
#   "diffusion_head_config": {
#     "ddpm_batch_mul": 4,
#     "ddpm_beta_schedule": "cosine",
#     "ddpm_num_inference_steps": 20,
#     "ddpm_num_steps": 1000,
#     "diffusion_type": "ddpm",
#     "head_ffn_ratio": 3.0,
#     "head_layers": 4,
#     "hidden_size": 1536,
#     "latent_size": 64,
#     "model_type": "vibevoice_diffusion_head",
#     "prediction_type": "v_prediction",
#     "rms_norm_eps": 1e-05,
#     "speech_vae_dim": 64
#   },
#   "model_type": "vibevoice",
#   "semantic_tokenizer_config": {
#     "causal": true,
#     "channels": 1,
#     "conv_bias": true,
#     "conv_norm": "none",
#     "corpus_normalize": 0.0,
#     "disable_last_norm": true,
#     "encoder_depths": "3-3-3-3-3-3-8",
#     "encoder_n_filters": 32,
#     "encoder_ratios": [
#       8,
#       5,
#       5,
#       4,
#       2,
#       2
#     ],
#     "fix_std": 0,
#     "layer_scale_init_value": 1e-06,
#     "layernorm": "RMSNorm",
#     "layernorm_elementwise_affine": true,
#     "layernorm_eps": 1e-05,
#     "mixer_layer": "depthwise_conv",
#     "model_type": "vibevoice_semantic_tokenizer",
#     "pad_mode": "constant",
#     "std_dist_type": "none",
#     "vae_dim": 128,
#     "weight_init_value": 0.01
#   },
#   "semantic_vae_dim": 128,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.51.3"
# }
#
# model.safetensors.index.json: 123kB [00:00, 226MB/s]
# loading weights file model.safetensors from cache at /root/.cache/huggingface/hub/models--microsoft--VibeVoice-1.5B/snapshots/cf42b8ff262f8a286bcbe580835cfaad62d277ca/model.safetensors.index.json
# Fetching 3 files:   0% 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0% 0.00/1.98G [00:00<?, ?B/s]
#
# model-00002-of-00003.safetensors:   0% 0.00/1.98G [00:00<?, ?B/s]
#
#
# model-00003-of-00003.safetensors:   0% 0.00/1.45G [00:00<?, ?B/s]
#
# model-00002-of-00003.safetensors:   0% 690k/1.98G [00:00<41:57, 787kB/s]
# model-00001-of-00003.safetensors:   0% 1.02M/1.98G [00:00<30:49, 1.07MB/s]
#
#
# model-00003-of-00003.safetensors:   0% 523k/1.45G [00:00<44:08, 547kB/s]
#
# model-00002-of-00003.safetensors:   3% 67.8M/1.98G [00:06<03:03, 10.4MB/s]
#
# model-00002-of-00003.safetensors:   7% 135M/1.98G [00:13<03:06, 9.91MB/s]
# model-00001-of-00003.safetensors:   0% 1.02M/1.98G [00:18<30:49, 1.07MB/s]
#
#
# model-00003-of-00003.safetensors:   0% 523k/1.45G [00:18<44:08, 547kB/s]
#
# model-00002-of-00003.safetensors:  17% 336M/1.98G [00:18<01:15, 21.7MB/s]
#
#
# model-00003-of-00003.safetensors:   5% 67.6M/1.45G [00:19<06:32, 3.52MB/s]
#
# model-00002-of-00003.safetensors:  24% 470M/1.98G [00:19<00:46, 32.7MB/s]
# model-00001-of-00003.safetensors:   3% 68.1M/1.98G [00:23<10:44, 2.96MB/s]
#
# model-00002-of-00003.safetensors:  30% 604M/1.98G [00:24<00:46, 29.8MB/s]
#
# model-00002-of-00003.safetensors:  37% 739M/1.98G [00:28<00:37, 32.8MB/s]
# model-00001-of-00003.safetensors:  10% 202M/1.98G [00:28<03:26, 8.60MB/s]
#
# model-00002-of-00003.safetensors:  41% 806M/1.98G [00:30<00:37, 31.4MB/s]
#
#
# model-00003-of-00003.safetensors:   9% 135M/1.45G [00:30<04:43, 4.64MB/s]
# model-00001-of-00003.safetensors:  17% 336M/1.98G [00:31<01:53, 14.4MB/s]
#
# model-00002-of-00003.safetensors:  44% 873M/1.98G [00:31<00:31, 34.9MB/s]
# model-00001-of-00003.safetensors:  24% 470M/1.98G [00:32<01:05, 22.9MB/s]
#
#
# model-00003-of-00003.safetensors:  14% 202M/1.45G [00:32<02:45, 7.56MB/s]
# model-00001-of-00003.safetensors:  27% 537M/1.98G [00:35<01:01, 23.2MB/s]
#
#
# model-00003-of-00003.safetensors:  19% 269M/1.45G [00:35<01:53, 10.4MB/s]
# model-00001-of-00003.safetensors:  31% 604M/1.98G [00:37<00:52, 26.1MB/s]
#
#
# model-00003-of-00003.safetensors:  23% 336M/1.45G [00:37<01:18, 14.2MB/s]
#
#
# model-00003-of-00003.safetensors:  28% 403M/1.45G [00:37<00:52, 20.1MB/s]
#
# model-00002-of-00003.safetensors:  47% 940M/1.98G [00:38<00:47, 22.0MB/s]
#
#
# model-00003-of-00003.safetensors:  32% 470M/1.45G [00:39<00:38, 25.3MB/s]
#
#
# model-00003-of-00003.safetensors:  37% 537M/1.45G [00:41<00:35, 25.6MB/s]
# model-00001-of-00003.safetensors:  34% 671M/1.98G [00:41<01:00, 21.6MB/s]
#
#
# model-00003-of-00003.safetensors:  42% 604M/1.45G [00:42<00:24, 33.9MB/s]
#
#
# model-00003-of-00003.safetensors:  46% 671M/1.45G [00:42<00:17, 44.9MB/s]
#
#
# model-00003-of-00003.safetensors:  51% 738M/1.45G [00:43<00:13, 53.2MB/s]
# model-00001-of-00003.safetensors:  37% 739M/1.98G [00:44<00:53, 23.1MB/s]
#
#
# model-00003-of-00003.safetensors:  56% 805M/1.45G [00:46<00:18, 34.6MB/s]
# model-00001-of-00003.safetensors:  41% 806M/1.98G [00:47<00:50, 23.0MB/s]
#
#
# model-00003-of-00003.safetensors:  60% 872M/1.45G [00:49<00:19, 30.1MB/s]
# model-00001-of-00003.safetensors:  44% 873M/1.98G [00:49<00:47, 23.2MB/s]
# model-00001-of-00003.safetensors:  48% 940M/1.98G [00:50<00:33, 30.9MB/s]
#
# model-00002-of-00003.safetensors:  51% 1.01G/1.98G [00:51<01:20, 12.2MB/s]
#
#
# model-00003-of-00003.safetensors:  65% 939M/1.45G [00:51<00:15, 33.8MB/s]
#
# model-00002-of-00003.safetensors:  54% 1.07G/1.98G [00:52<00:57, 15.7MB/s]
#
# model-00002-of-00003.safetensors:  58% 1.14G/1.98G [00:52<00:40, 20.8MB/s]
#
#
# model-00003-of-00003.safetensors:  69% 1.01G/1.45G [00:52<00:12, 36.7MB/s]
# model-00001-of-00003.safetensors:  51% 1.01G/1.98G [00:53<00:35, 26.9MB/s]
#
#
# model-00003-of-00003.safetensors:  74% 1.07G/1.45G [00:53<00:09, 40.4MB/s]
#
#
# model-00003-of-00003.safetensors:  79% 1.14G/1.45G [00:54<00:05, 52.7MB/s]
#
#
# model-00003-of-00003.safetensors:  83% 1.21G/1.45G [00:54<00:03, 64.5MB/s]
#
# model-00002-of-00003.safetensors:  61% 1.21G/1.98G [00:56<00:38, 20.2MB/s]
# model-00001-of-00003.safetensors:  54% 1.07G/1.98G [00:56<00:35, 25.1MB/s]
# model-00001-of-00003.safetensors:  56% 1.10G/1.98G [00:56<00:29, 29.2MB/s]
#
#
# model-00003-of-00003.safetensors:  86% 1.25G/1.45G [00:58<00:05, 34.1MB/s]
#
# model-00002-of-00003.safetensors:  64% 1.27G/1.98G [01:04<00:49, 14.3MB/s]
# model-00001-of-00003.safetensors:  59% 1.17G/1.98G [01:07<01:00, 13.4MB/s]
#
#
# model-00003-of-00003.safetensors:  86% 1.25G/1.45G [01:08<00:05, 34.1MB/s]
#
#
# model-00003-of-00003.safetensors:  91% 1.32G/1.45G [01:09<00:09, 13.7MB/s]
# model-00001-of-00003.safetensors:  63% 1.24G/1.98G [01:09<00:44, 16.6MB/s]
#
# model-00002-of-00003.safetensors:  70% 1.38G/1.98G [01:09<00:37, 15.9MB/s]
#
# model-00002-of-00003.safetensors:  73% 1.45G/1.98G [01:11<00:28, 18.7MB/s]
# model-00001-of-00003.safetensors:  66% 1.31G/1.98G [01:12<00:37, 17.9MB/s]
#
# model-00002-of-00003.safetensors:  76% 1.51G/1.98G [01:12<00:20, 23.1MB/s]
# model-00001-of-00003.safetensors:  69% 1.37G/1.98G [01:13<00:26, 23.1MB/s]
#
# model-00002-of-00003.safetensors:  80% 1.58G/1.98G [01:13<00:14, 28.6MB/s]
# model-00001-of-00003.safetensors:  73% 1.44G/1.98G [01:16<00:23, 22.7MB/s]
#
# model-00002-of-00003.safetensors:  83% 1.65G/1.98G [01:16<00:12, 26.4MB/s]
#
#
# model-00003-of-00003.safetensors:  95% 1.38G/1.45G [01:18<00:06, 10.7MB/s]
#
# model-00002-of-00003.safetensors:  86% 1.71G/1.98G [01:20<00:11, 22.4MB/s]
# model-00001-of-00003.safetensors:  76% 1.51G/1.98G [01:20<00:23, 20.0MB/s]
# model-00001-of-00003.safetensors:  80% 1.57G/1.98G [01:21<00:14, 27.5MB/s]
# model-00001-of-00003.safetensors:  83% 1.64G/1.98G [01:21<00:09, 35.9MB/s]
#
# model-00002-of-00003.safetensors:  90% 1.78G/1.98G [01:22<00:07, 26.0MB/s]
# model-00001-of-00003.safetensors:  86% 1.71G/1.98G [01:22<00:06, 41.3MB/s]
#
# model-00002-of-00003.safetensors:  93% 1.85G/1.98G [01:23<00:04, 31.4MB/s]
# model-00001-of-00003.safetensors:  90% 1.77G/1.98G [01:23<00:04, 45.9MB/s]
# model-00001-of-00003.safetensors:  93% 1.84G/1.98G [01:24<00:02, 55.9MB/s]
# model-00001-of-00003.safetensors:  97% 1.91G/1.98G [01:24<00:00, 67.9MB/s]
#
#
# model-00003-of-00003.safetensors: 100% 1.45G/1.45G [01:25<00:00, 16.9MB/s]
#
# model-00001-of-00003.safetensors: 100% 1.98G/1.98G [01:25<00:00, 23.0MB/s]
# Fetching 3 files:  33% 1/3 [01:26<02:52, 86.06s/it]
#
# model-00002-of-00003.safetensors:  97% 1.92G/1.98G [01:26<00:02, 27.0MB/s]
#
# model-00002-of-00003.safetensors: 100% 1.98G/1.98G [01:26<00:00, 22.9MB/s]
# Fetching 3 files: 100% 3/3 [01:26<00:00, 28.99s/it]
# Instantiating VibeVoiceForConditionalGenerationInference model under default dtype torch.bfloat16.
# [ERROR] : ImportError: FlashAttention2 has been toggled on, but it cannot be used due to the following error: the package flash_attn seems to be not installed. Please refer to the documentation of https://huggingface.co/docs/transformers/perf_infer_gpu_one#flashattention-2 to install Flash Attention 2.
# Traceback (most recent call last):
#   File "/content/VibeVoice/demo/inference_from_file.py", line 250, in main
#     model = VibeVoiceForConditionalGenerationInference.from_pretrained(
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/modeling_utils.py", line 279, in _wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/modeling_utils.py", line 4336, in from_pretrained
#     config = cls._autoset_attn_implementation(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/modeling_utils.py", line 2109, in _autoset_attn_implementation
#     cls._check_and_enable_flash_attn_2(
#   File "/usr/local/lib/python3.12/dist-packages/transformers/modeling_utils.py", line 2252, in _check_and_enable_flash_attn_2
#     raise ImportError(f"{preface} the package flash_attn seems to be not installed. {install_message}")
# ImportError: FlashAttention2 has been toggled on, but it cannot be used due to the following error: the package flash_attn seems to be not installed. Please refer to the documentation of https://huggingface.co/docs/transformers/perf_infer_gpu_one#flashattention-2 to install Flash Attention 2.
#
# Error loading the model. Trying to use SDPA. However, note that only flash_attention_2 has been fully tested, and using SDPA may result in lower audio quality.
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--microsoft--VibeVoice-1.5B/snapshots/cf42b8ff262f8a286bcbe580835cfaad62d277ca/config.json
# Model config VibeVoiceConfig {
#   "acoustic_tokenizer_config": {
#     "causal": true,
#     "channels": 1,
#     "conv_bias": true,
#     "conv_norm": "none",
#     "corpus_normalize": 0.0,
#     "decoder_depths": null,
#     "decoder_n_filters": 32,
#     "decoder_ratios": [
#       8,
#       5,
#       5,
#       4,
#       2,
#       2
#     ],
#     "disable_last_norm": true,
#     "encoder_depths": "3-3-3-3-3-3-8",
#     "encoder_n_filters": 32,
#     "encoder_ratios": [
#       8,
#       5,
#       5,
#       4,
#       2,
#       2
#     ],
#     "fix_std": 0.5,
#     "layer_scale_init_value": 1e-06,
#     "layernorm": "RMSNorm",
#     "layernorm_elementwise_affine": true,
#     "layernorm_eps": 1e-05,
#     "mixer_layer": "depthwise_conv",
#     "model_type": "vibevoice_acoustic_tokenizer",
#     "pad_mode": "constant",
#     "std_dist_type": "gaussian",
#     "vae_dim": 64,
#     "weight_init_value": 0.01
#   },
#   "acoustic_vae_dim": 64,
#   "architectures": [
#     "VibeVoiceForConditionalGeneration"
#   ],
#   "decoder_config": {
#     "attention_dropout": 0.0,
#     "hidden_act": "silu",
#     "hidden_size": 1536,
#     "initializer_range": 0.02,
#     "intermediate_size": 8960,
#     "max_position_embeddings": 65536,
#     "max_window_layers": 28,
#     "model_type": "qwen2",
#     "num_attention_heads": 12,
#     "num_hidden_layers": 28,
#     "num_key_value_heads": 2,
#     "rms_norm_eps": 1e-06,
#     "rope_scaling": null,
#     "rope_theta": 1000000.0,
#     "sliding_window": null,
#     "tie_word_embeddings": true,
#     "torch_dtype": "bfloat16",
#     "use_cache": true,
#     "use_sliding_window": false,
#     "vocab_size": 151936
#   },
#   "diffusion_head_config": {
#     "ddpm_batch_mul": 4,
#     "ddpm_beta_schedule": "cosine",
#     "ddpm_num_inference_steps": 20,
#     "ddpm_num_steps": 1000,
#     "diffusion_type": "ddpm",
#     "head_ffn_ratio": 3.0,
#     "head_layers": 4,
#     "hidden_size": 1536,
#     "latent_size": 64,
#     "model_type": "vibevoice_diffusion_head",
#     "prediction_type": "v_prediction",
#     "rms_norm_eps": 1e-05,
#     "speech_vae_dim": 64
#   },
#   "model_type": "vibevoice",
#   "semantic_tokenizer_config": {
#     "causal": true,
#     "channels": 1,
#     "conv_bias": true,
#     "conv_norm": "none",
#     "corpus_normalize": 0.0,
#     "disable_last_norm": true,
#     "encoder_depths": "3-3-3-3-3-3-8",
#     "encoder_n_filters": 32,
#     "encoder_ratios": [
#       8,
#       5,
#       5,
#       4,
#       2,
#       2
#     ],
#     "fix_std": 0,
#     "layer_scale_init_value": 1e-06,
#     "layernorm": "RMSNorm",
#     "layernorm_elementwise_affine": true,
#     "layernorm_eps": 1e-05,
#     "mixer_layer": "depthwise_conv",
#     "model_type": "vibevoice_semantic_tokenizer",
#     "pad_mode": "constant",
#     "std_dist_type": "none",
#     "vae_dim": 128,
#     "weight_init_value": 0.01
#   },
#   "semantic_vae_dim": 128,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.51.3"
# }
#
# loading weights file model.safetensors from cache at /root/.cache/huggingface/hub/models--microsoft--VibeVoice-1.5B/snapshots/cf42b8ff262f8a286bcbe580835cfaad62d277ca/model.safetensors.index.json
# Instantiating VibeVoiceForConditionalGenerationInference model under default dtype torch.bfloat16.
# Generate config GenerationConfig {}
#
# Instantiating Qwen2Model model under default dtype torch.bfloat16.
# Instantiating VibeVoiceAcousticTokenizerModel model under default dtype torch.bfloat16.
# Instantiating VibeVoiceSemanticTokenizerModel model under default dtype torch.bfloat16.
# Instantiating VibeVoiceDiffusionHead model under default dtype torch.bfloat16.
# Loading checkpoint shards: 100% 3/3 [00:23<00:00,  7.70s/it]
# All model checkpoint weights were used when initializing VibeVoiceForConditionalGenerationInference.
#
# All the weights of VibeVoiceForConditionalGenerationInference were initialized from the model checkpoint at microsoft/VibeVoice-1.5B.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use VibeVoiceForConditionalGenerationInference for predictions without further training.
# Generation config file not found, using a generation config created from the model config.
# Language model attention: sdpa
# Starting generation with cfg_scale: 1.3
# Generating (active: 1/1):  15% 107/702 [00:26<02:11,  4.52it/s]Samples [0] reached EOS token at step 109.
# Generation time: 26.63 seconds
# Generated audio duration: 14.27 seconds
# RTF (Real Time Factor): 1.87x
# Prefilling tokens: 351
# Generated tokens: 109
# Total tokens: 460
# Saved output to ./outputs/2p_short_generated.wav
#
# ==================================================
# GENERATION SUMMARY
# ==================================================
# Input file: demo/text_examples/2p_short.txt
# Output file: ./outputs/2p_short_generated.wav
# Speaker names: ['Alice', 'Frank']
# Number of unique speakers: 2
# Number of segments: 2
# Prefilling tokens: 351
# Generated tokens: 109
# Total tokens: 460
# Generation time: 26.63 seconds
# Audio duration: 14.27 seconds
# RTF (Real Time Factor): 1.87x
# ==================================================
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### TTS from your text

# %%
text = """Speaker 1: Can I try VibeVoice with my own example?
Speaker 2: Of course! VibeVoice is open-source, built to benefit everyone — you’re welcome to try it out."""
with open("demo/text_examples/my_example.txt", "w", encoding="utf-8") as f:
    f.write(text)

# %%
# !python demo/inference_from_file.py --model_path microsoft/VibeVoice-1.5B --txt_path demo/text_examples/my_example.txt --speaker_names Alice Frank
Audio("./outputs/my_example_generated.wav")
# Out:
# 2025-08-28 16:11:46.269180: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1756397506.288680    5356 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1756397506.294707    5356 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1756397506.310220    5356 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1756397506.310253    5356 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1756397506.310257    5356 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1756397506.310261    5356 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-08-28 16:11:46.314913: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:vibevoice.modular.modular_vibevoice_tokenizer:APEX FusedRMSNorm not available, using native implementation
# Found 9 voice files in /content/VibeVoice/demo/voices
# Available voices: en-Alice_woman, en-Carter_man, en-Frank_man, en-Mary_woman_bgm, en-Maya_woman, in-Samuel_man, zh-Anchen_man_bgm, zh-Bowen_man, zh-Xinran_woman
# Reading script from: demo/text_examples/my_example.txt
# Found 2 speaker segments:
#   1. Speaker 1
#      Text preview: Speaker 1: Can I try VibeVoice with my own example?...
#   2. Speaker 2
#      Text preview: Speaker 2: Of course! VibeVoice is open-source, built to benefit everyone — you’re welcome to try it...
#
# Speaker mapping:
#   Speaker 1 -> Alice
#   Speaker 2 -> Frank
# Speaker 1 ('Alice') -> Voice: en-Alice_woman.wav
# Speaker 2 ('Frank') -> Voice: en-Frank_man.wav
# Loading processor & model from microsoft/VibeVoice-1.5B
# WARNING:vibevoice.processor.vibevoice_processor:No preprocessor_config.json found at microsoft/VibeVoice-1.5B, using defaults
# loading file vocab.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B/snapshots/8faed761d45a263340a0528343f099c05c9a4323/vocab.json
# loading file merges.txt from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B/snapshots/8faed761d45a263340a0528343f099c05c9a4323/merges.txt
# loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B/snapshots/8faed761d45a263340a0528343f099c05c9a4323/tokenizer.json
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at None
# loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-1.5B/snapshots/8faed761d45a263340a0528343f099c05c9a4323/tokenizer_config.json
# loading file chat_template.jinja from cache at None
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'Qwen2Tokenizer'.
# The class this function is called from is 'VibeVoiceTextTokenizerFast'.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--microsoft--VibeVoice-1.5B/snapshots/cf42b8ff262f8a286bcbe580835cfaad62d277ca/config.json
# Model config VibeVoiceConfig {
#   "acoustic_tokenizer_config": {
#     "causal": true,
#     "channels": 1,
#     "conv_bias": true,
#     "conv_norm": "none",
#     "corpus_normalize": 0.0,
#     "decoder_depths": null,
#     "decoder_n_filters": 32,
#     "decoder_ratios": [
#       8,
#       5,
#       5,
#       4,
#       2,
#       2
#     ],
#     "disable_last_norm": true,
#     "encoder_depths": "3-3-3-3-3-3-8",
#     "encoder_n_filters": 32,
#     "encoder_ratios": [
#       8,
#       5,
#       5,
#       4,
#       2,
#       2
#     ],
#     "fix_std": 0.5,
#     "layer_scale_init_value": 1e-06,
#     "layernorm": "RMSNorm",
#     "layernorm_elementwise_affine": true,
#     "layernorm_eps": 1e-05,
#     "mixer_layer": "depthwise_conv",
#     "model_type": "vibevoice_acoustic_tokenizer",
#     "pad_mode": "constant",
#     "std_dist_type": "gaussian",
#     "vae_dim": 64,
#     "weight_init_value": 0.01
#   },
#   "acoustic_vae_dim": 64,
#   "architectures": [
#     "VibeVoiceForConditionalGeneration"
#   ],
#   "decoder_config": {
#     "attention_dropout": 0.0,
#     "hidden_act": "silu",
#     "hidden_size": 1536,
#     "initializer_range": 0.02,
#     "intermediate_size": 8960,
#     "max_position_embeddings": 65536,
#     "max_window_layers": 28,
#     "model_type": "qwen2",
#     "num_attention_heads": 12,
#     "num_hidden_layers": 28,
#     "num_key_value_heads": 2,
#     "rms_norm_eps": 1e-06,
#     "rope_scaling": null,
#     "rope_theta": 1000000.0,
#     "sliding_window": null,
#     "tie_word_embeddings": true,
#     "torch_dtype": "bfloat16",
#     "use_cache": true,
#     "use_sliding_window": false,
#     "vocab_size": 151936
#   },
#   "diffusion_head_config": {
#     "ddpm_batch_mul": 4,
#     "ddpm_beta_schedule": "cosine",
#     "ddpm_num_inference_steps": 20,
#     "ddpm_num_steps": 1000,
#     "diffusion_type": "ddpm",
#     "head_ffn_ratio": 3.0,
#     "head_layers": 4,
#     "hidden_size": 1536,
#     "latent_size": 64,
#     "model_type": "vibevoice_diffusion_head",
#     "prediction_type": "v_prediction",
#     "rms_norm_eps": 1e-05,
#     "speech_vae_dim": 64
#   },
#   "model_type": "vibevoice",
#   "semantic_tokenizer_config": {
#     "causal": true,
#     "channels": 1,
#     "conv_bias": true,
#     "conv_norm": "none",
#     "corpus_normalize": 0.0,
#     "disable_last_norm": true,
#     "encoder_depths": "3-3-3-3-3-3-8",
#     "encoder_n_filters": 32,
#     "encoder_ratios": [
#       8,
#       5,
#       5,
#       4,
#       2,
#       2
#     ],
#     "fix_std": 0,
#     "layer_scale_init_value": 1e-06,
#     "layernorm": "RMSNorm",
#     "layernorm_elementwise_affine": true,
#     "layernorm_eps": 1e-05,
#     "mixer_layer": "depthwise_conv",
#     "model_type": "vibevoice_semantic_tokenizer",
#     "pad_mode": "constant",
#     "std_dist_type": "none",
#     "vae_dim": 128,
#     "weight_init_value": 0.01
#   },
#   "semantic_vae_dim": 128,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.51.3"
# }
#
# loading weights file model.safetensors from cache at /root/.cache/huggingface/hub/models--microsoft--VibeVoice-1.5B/snapshots/cf42b8ff262f8a286bcbe580835cfaad62d277ca/model.safetensors.index.json
# Instantiating VibeVoiceForConditionalGenerationInference model under default dtype torch.bfloat16.
# [ERROR] : ImportError: FlashAttention2 has been toggled on, but it cannot be used due to the following error: the package flash_attn seems to be not installed. Please refer to the documentation of https://huggingface.co/docs/transformers/perf_infer_gpu_one#flashattention-2 to install Flash Attention 2.
# Traceback (most recent call last):
#   File "/content/VibeVoice/demo/inference_from_file.py", line 250, in main
#     model = VibeVoiceForConditionalGenerationInference.from_pretrained(
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/modeling_utils.py", line 279, in _wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/modeling_utils.py", line 4336, in from_pretrained
#     config = cls._autoset_attn_implementation(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/modeling_utils.py", line 2109, in _autoset_attn_implementation
#     cls._check_and_enable_flash_attn_2(
#   File "/usr/local/lib/python3.12/dist-packages/transformers/modeling_utils.py", line 2252, in _check_and_enable_flash_attn_2
#     raise ImportError(f"{preface} the package flash_attn seems to be not installed. {install_message}")
# ImportError: FlashAttention2 has been toggled on, but it cannot be used due to the following error: the package flash_attn seems to be not installed. Please refer to the documentation of https://huggingface.co/docs/transformers/perf_infer_gpu_one#flashattention-2 to install Flash Attention 2.
#
# Error loading the model. Trying to use SDPA. However, note that only flash_attention_2 has been fully tested, and using SDPA may result in lower audio quality.
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--microsoft--VibeVoice-1.5B/snapshots/cf42b8ff262f8a286bcbe580835cfaad62d277ca/config.json
# Model config VibeVoiceConfig {
#   "acoustic_tokenizer_config": {
#     "causal": true,
#     "channels": 1,
#     "conv_bias": true,
#     "conv_norm": "none",
#     "corpus_normalize": 0.0,
#     "decoder_depths": null,
#     "decoder_n_filters": 32,
#     "decoder_ratios": [
#       8,
#       5,
#       5,
#       4,
#       2,
#       2
#     ],
#     "disable_last_norm": true,
#     "encoder_depths": "3-3-3-3-3-3-8",
#     "encoder_n_filters": 32,
#     "encoder_ratios": [
#       8,
#       5,
#       5,
#       4,
#       2,
#       2
#     ],
#     "fix_std": 0.5,
#     "layer_scale_init_value": 1e-06,
#     "layernorm": "RMSNorm",
#     "layernorm_elementwise_affine": true,
#     "layernorm_eps": 1e-05,
#     "mixer_layer": "depthwise_conv",
#     "model_type": "vibevoice_acoustic_tokenizer",
#     "pad_mode": "constant",
#     "std_dist_type": "gaussian",
#     "vae_dim": 64,
#     "weight_init_value": 0.01
#   },
#   "acoustic_vae_dim": 64,
#   "architectures": [
#     "VibeVoiceForConditionalGeneration"
#   ],
#   "decoder_config": {
#     "attention_dropout": 0.0,
#     "hidden_act": "silu",
#     "hidden_size": 1536,
#     "initializer_range": 0.02,
#     "intermediate_size": 8960,
#     "max_position_embeddings": 65536,
#     "max_window_layers": 28,
#     "model_type": "qwen2",
#     "num_attention_heads": 12,
#     "num_hidden_layers": 28,
#     "num_key_value_heads": 2,
#     "rms_norm_eps": 1e-06,
#     "rope_scaling": null,
#     "rope_theta": 1000000.0,
#     "sliding_window": null,
#     "tie_word_embeddings": true,
#     "torch_dtype": "bfloat16",
#     "use_cache": true,
#     "use_sliding_window": false,
#     "vocab_size": 151936
#   },
#   "diffusion_head_config": {
#     "ddpm_batch_mul": 4,
#     "ddpm_beta_schedule": "cosine",
#     "ddpm_num_inference_steps": 20,
#     "ddpm_num_steps": 1000,
#     "diffusion_type": "ddpm",
#     "head_ffn_ratio": 3.0,
#     "head_layers": 4,
#     "hidden_size": 1536,
#     "latent_size": 64,
#     "model_type": "vibevoice_diffusion_head",
#     "prediction_type": "v_prediction",
#     "rms_norm_eps": 1e-05,
#     "speech_vae_dim": 64
#   },
#   "model_type": "vibevoice",
#   "semantic_tokenizer_config": {
#     "causal": true,
#     "channels": 1,
#     "conv_bias": true,
#     "conv_norm": "none",
#     "corpus_normalize": 0.0,
#     "disable_last_norm": true,
#     "encoder_depths": "3-3-3-3-3-3-8",
#     "encoder_n_filters": 32,
#     "encoder_ratios": [
#       8,
#       5,
#       5,
#       4,
#       2,
#       2
#     ],
#     "fix_std": 0,
#     "layer_scale_init_value": 1e-06,
#     "layernorm": "RMSNorm",
#     "layernorm_elementwise_affine": true,
#     "layernorm_eps": 1e-05,
#     "mixer_layer": "depthwise_conv",
#     "model_type": "vibevoice_semantic_tokenizer",
#     "pad_mode": "constant",
#     "std_dist_type": "none",
#     "vae_dim": 128,
#     "weight_init_value": 0.01
#   },
#   "semantic_vae_dim": 128,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.51.3"
# }
#
# loading weights file model.safetensors from cache at /root/.cache/huggingface/hub/models--microsoft--VibeVoice-1.5B/snapshots/cf42b8ff262f8a286bcbe580835cfaad62d277ca/model.safetensors.index.json
# Instantiating VibeVoiceForConditionalGenerationInference model under default dtype torch.bfloat16.
# Generate config GenerationConfig {}
#
# Instantiating Qwen2Model model under default dtype torch.bfloat16.
# Instantiating VibeVoiceAcousticTokenizerModel model under default dtype torch.bfloat16.
# Instantiating VibeVoiceSemanticTokenizerModel model under default dtype torch.bfloat16.
# Instantiating VibeVoiceDiffusionHead model under default dtype torch.bfloat16.
# Loading checkpoint shards: 100% 3/3 [00:24<00:00,  8.30s/it]
# All model checkpoint weights were used when initializing VibeVoiceForConditionalGenerationInference.
#
# All the weights of VibeVoiceForConditionalGenerationInference were initialized from the model checkpoint at microsoft/VibeVoice-1.5B.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use VibeVoiceForConditionalGenerationInference for predictions without further training.
# Generation config file not found, using a generation config created from the model config.
# Language model attention: sdpa
# Starting generation with cfg_scale: 1.3
# Generating (active: 1/1):   8% 57/674 [00:15<02:11,  4.71it/s]Samples [0] reached EOS token at step 59.
# Generation time: 15.53 seconds
# Generated audio duration: 7.60 seconds
# RTF (Real Time Factor): 2.04x
# Prefilling tokens: 337
# Generated tokens: 59
# Total tokens: 396
# Saved output to ./outputs/my_example_generated.wav
#
# ==================================================
# GENERATION SUMMARY
# ==================================================
# Input file: demo/text_examples/my_example.txt
# Output file: ./outputs/my_example_generated.wav
# Speaker names: ['Alice', 'Frank']
# Number of unique speakers: 2
# Number of segments: 2
# Prefilling tokens: 337
# Generated tokens: 59
# Total tokens: 396
# Generation time: 15.53 seconds
# Audio duration: 7.60 seconds
# RTF (Real Time Factor): 2.04x
# ==================================================
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Risk and Limitations

# %% [markdown]
# While efforts have been made to optimize it through various techniques, it may still produce outputs that are unexpected, biased, or inaccurate. VibeVoice inherits any biases, errors, or omissions produced by its base model (specifically, Qwen2.5 1.5b in this release). Potential for Deepfakes and Disinformation: High-quality synthetic speech can be misused to create convincing fake audio content for impersonation, fraud, or spreading disinformation. Users must ensure transcripts are reliable, check content accuracy, and avoid using generated content in misleading ways. Users are expected to use the generated content and to deploy the models in a lawful manner, in full compliance with all applicable laws and regulations in the relevant jurisdictions. It is best practice to disclose the use of AI when sharing AI-generated content.
